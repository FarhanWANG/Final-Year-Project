# %%
# %matplotlib inline

from pathlib import Path

import numpy as np
import pandas as pd
import pandas_datareader.data as web
from scipy.stats import spearmanr

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow import keras

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using GPU

# %%
sns.set_style('whitegrid')
np.random.seed(42)
# pd.set_option('display.max_rows',None)

# %%
import datetime
CC100_Index = pd.read_csv("indexReturns-BITW100.csv")
CC100_Index['date'] = pd.to_datetime(CC100_Index['date']).dt.tz_localize(None)
CC100_Index = CC100_Index.sort_values('date').set_index('date')
CC100_Index = CC100_Index.truncate(before = datetime.datetime(2020,1,1),after = datetime.datetime(2020,12,31))
date_s = pd.Series([i.strftime('%F') for i in CC100_Index.index])
CC100_Index = CC100_Index.reset_index()
CC100_Index['date'] = date_s
CC100_Index = CC100_Index.set_index(['date'])
CC100_Index['Market_Return'] = np.log(CC100_Index/CC100_Index.shift()).fillna(0)
CC100_Index
# Out:
#             MarketIndex  Market_Return
# date
# 2020-01-01      7068.77       0.000000
# 2020-01-02      6778.93      -0.041867
# 2020-01-03      7152.82       0.053687
# 2020-01-04      7177.27       0.003412
# 2020-01-05      7296.59       0.016488
# ...                 ...            ...
# 2020-12-26     24145.53       0.069255
# 2020-12-27     23984.01      -0.006712
# 2020-12-28     24895.42       0.037296
# 2020-12-29     24925.16       0.001194
# 2020-12-30     26338.46       0.055152
#
# [365 rows x 2 columns]

# %% [markdown]
# # For any time T (starting from Jan 1st  2020) in the test set, we have the top 10 CC in time T. For each CC, we train the model using data from 2017 to 2019. And use the model to predict the return of time (T+1) given the data of T-90 to T.

# %% [markdown]
# ## Detailed Steps:
# ### Find all the top10 CC from Jan 2020 and train each model using data from 2017 to 2019.
# ### Then for each day T after Jan 2020, we find the top10 CC and combine the exising models with their data of T-90 to T to predict T+1.
# ### Then fit the return of T+1 to into mean-variance model to get the optimal CC allocation
# ### Then test the performance of the strategy

# %% [markdown]
# ### Find all the top10 CC from Jan 2020

# %%
import ast
def find_all_top10CC(date,top10CC,category):
    df_temp = top10CC.loc[date:][category]
    ls_temp = []
    for i in df_temp:
        ls_temp += ast.literal_eval(i)
    return list(set(ls_temp))

# %%
TEST_START = '2020-01-01'
top10CC = pd.read_csv('top10CC_daily.csv').set_index('date')
top10CC_Liquid_test = find_all_top10CC(TEST_START, top10CC, 'top10_Liquid')
top10CC_MarketCap_test = find_all_top10CC(TEST_START, top10CC, 'top10_Market')

# %% [markdown]
# ### Train each model using data from 2017 to 2019.

# %%
# Generating recurrent sequences from time series
def create_univariate_rnn_data(data, window_size):
    n = len(data)
    y = data[window_size:]
    data = data.values.reshape(-1, 1) # make 2D
    X = np.hstack(tuple([data[i: n-j, :] for i, j in enumerate(range(window_size, 0, -1))]))
    return pd.DataFrame(X, index=y.index), y

# %%
results_path = Path('results', 'univariate_LSTM')
if not results_path.exists():
    results_path.mkdir(parents=True)

# %%
def train_model(CC_name):
    print("-"*150+"\n"+"-"*150+"\n"+" "*75+CC_name+"\n"+"-"*150+"\n"+"-"*150)
    
    # Preprocessing data
    df=pd.read_csv('CC_daily_data.csv').dropna()
    
    dfclose = df[df['ticker']==(CC_name+'-USD')].set_index(['date'])['close'].to_frame()
    dfclose = dfclose[~dfclose.index.duplicated(keep = 'first')]
    dfreturn = (np.log(dfclose/dfclose.shift())
                .dropna()
                .rename(columns = {'close':'return'}))

    # Scaling data
    scaler = MinMaxScaler()
    dfreturn_scaled = pd.Series(scaler.fit_transform(dfreturn).squeeze(),index =dfreturn.index)
    dfreturn_scaled.describe()
    
    window_size = 90
    X,y = create_univariate_rnn_data(dfreturn_scaled, window_size)
    
    # Train-Test split
    X_train = X[:'2020'].values.reshape(-1, window_size, 1)
    y_train = y[:'2020']

    # keep the last year for testing
    X_test = X['2020':].values.reshape(-1, window_size, 1)
    y_test = y['2020':]
    
    # define model architechture
    n_obs, window_size, n_features = X_train.shape
    rnn_return = Sequential([
        LSTM(units = 10, input_shape = (window_size,n_features), name='LSTM'),
        Dense(1, name='Output')
    ])
    
    # define model optimizer
    optimizer = keras.optimizers.RMSprop(lr=.001, rho = .9, epsilon = 1e-08, decay = .0)
    rnn_return.compile(loss = 'mean_squared_error', optimizer = optimizer)
    
    # define checkpointer and early_stoppint point
    rnn_path = (results_path / 'rnn.h5').as_posix()
    checkpointer = ModelCheckpoint(filepath=rnn_path,verbose=1,monitor='val_loss',save_best_only=True)
    early_stopping = EarlyStopping(monitor = 'val_loss',patience = 20, restore_best_weights = True)
    
    # train the model
    lstm_training_return = rnn_return.fit(X_train,y_train, epochs = 150, batch_size = 20, shuffle = True, validation_data=(X_test,y_test),callbacks = [early_stopping,checkpointer],verbose =1)
    
    # prediction
    train_predict_scaled = rnn_return.predict(X_train)
    test_predict_scaled = rnn_return.predict(X_test)
    
    # rescale predictions
    train_predict = pd.Series(scaler.inverse_transform(train_predict_scaled).squeeze(), index=y_train.index)
    test_predict = (pd.Series(scaler.inverse_transform(test_predict_scaled).squeeze(), index=y_test.index))
    
    
    dfreturn['Train Predictions'] = train_predict
    dfreturn['Test Predictions'] = test_predict
    dfreturn = dfreturn.join(train_predict.to_frame('predictions').assign(data='Train')
                            .append(test_predict.to_frame('predictions').assign(data='Test')))
    
    
    model_test = dfreturn.copy().fillna(0)
    tmp = model_test['return']*model_test['predictions'][-30:]
    accuracy = len(tmp[tmp>0])/30
    print(f'Test accuracy: {accuracy:.2f}')
    
    return dfreturn

# %% [markdown]
# ### Train models using  top10 market cap CC

# %%
for CC_name in top10CC_MarketCap_test:
    exec(f"data_{CC_name} = train_model(CC_name)")
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                            EOS
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/150
# 42/42 [==============================] - 4s 41ms/step - loss: 0.0484 - val_loss: 0.0013
#
# Epoch 00001: val_loss improved from inf to 0.00132, saving model to results/univariate_LSTM\rnn.h5
# Epoch 2/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0014
#
# Epoch 00002: val_loss did not improve from 0.00132
# Epoch 3/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0014
#
# Epoch 00003: val_loss did not improve from 0.00132
# Epoch 4/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0013
#
# Epoch 00004: val_loss did not improve from 0.00132
# Epoch 5/150
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00005: val_loss did not improve from 0.00132
# Epoch 6/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0014
#
# Epoch 00006: val_loss did not improve from 0.00132
# Epoch 7/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0018
#
# Epoch 00007: val_loss did not improve from 0.00132
# Epoch 8/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0016
#
# Epoch 00008: val_loss did not improve from 0.00132
# Epoch 9/150
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0023 - val_loss: 0.0019
#
# Epoch 00009: val_loss did not improve from 0.00132
# Epoch 10/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0013
#
# Epoch 00010: val_loss did not improve from 0.00132
# Epoch 11/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0017
#
# Epoch 00011: val_loss did not improve from 0.00132
# Epoch 12/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0014
#
# Epoch 00012: val_loss did not improve from 0.00132
# Epoch 13/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0013
#
# Epoch 00013: val_loss did not improve from 0.00132
# Epoch 14/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0016
#
# Epoch 00014: val_loss did not improve from 0.00132
# Epoch 15/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0013
#
# Epoch 00015: val_loss did not improve from 0.00132
# Epoch 16/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0024
#
# Epoch 00016: val_loss did not improve from 0.00132
# Epoch 17/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00017: val_loss did not improve from 0.00132
# Epoch 18/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0014
#
# Epoch 00018: val_loss did not improve from 0.00132
# Epoch 19/150
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0024 - val_loss: 0.0013
#
# Epoch 00019: val_loss did not improve from 0.00132
# Epoch 20/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00020: val_loss did not improve from 0.00132
# Epoch 21/150
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0013
#
# Epoch 00021: val_loss did not improve from 0.00132
# Test accuracy: 0.40
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                            ETH
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/150
# 51/51 [==============================] - 3s 22ms/step - loss: 0.0493 - val_loss: 0.0061
#
# Epoch 00001: val_loss improved from inf to 0.00614, saving model to results/univariate_LSTM\rnn.h5
# Epoch 2/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0049 - val_loss: 0.0046
#
# Epoch 00002: val_loss improved from 0.00614 to 0.00455, saving model to results/univariate_LSTM\rnn.h5
# Epoch 3/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0043
#
# Epoch 00003: val_loss improved from 0.00455 to 0.00430, saving model to results/univariate_LSTM\rnn.h5
# Epoch 4/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0070
#
# Epoch 00004: val_loss did not improve from 0.00430
# Epoch 5/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0050 - val_loss: 0.0046
#
# Epoch 00005: val_loss did not improve from 0.00430
# Epoch 6/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0046 - val_loss: 0.0041
#
# Epoch 00006: val_loss improved from 0.00430 to 0.00412, saving model to results/univariate_LSTM\rnn.h5
# Epoch 7/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0043
#
# Epoch 00007: val_loss did not improve from 0.00412
# Epoch 8/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0058
#
# Epoch 00008: val_loss did not improve from 0.00412
# Epoch 9/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0049
#
# Epoch 00009: val_loss did not improve from 0.00412
# Epoch 10/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0063
#
# Epoch 00010: val_loss did not improve from 0.00412
# Epoch 11/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0041
#
# Epoch 00011: val_loss improved from 0.00412 to 0.00410, saving model to results/univariate_LSTM\rnn.h5
# Epoch 12/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0062
#
# Epoch 00012: val_loss did not improve from 0.00410
# Epoch 13/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0041
#
# Epoch 00013: val_loss improved from 0.00410 to 0.00409, saving model to results/univariate_LSTM\rnn.h5
# Epoch 14/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0061
#
# Epoch 00014: val_loss did not improve from 0.00409
# Epoch 15/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0051 - val_loss: 0.0045
#
# Epoch 00015: val_loss did not improve from 0.00409
# Epoch 16/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0043
#
# Epoch 00016: val_loss did not improve from 0.00409
# Epoch 17/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0042 - val_loss: 0.0049
#
# Epoch 00017: val_loss did not improve from 0.00409
# Epoch 18/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0044
#
# Epoch 00018: val_loss did not improve from 0.00409
# Epoch 19/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0050
#
# Epoch 00019: val_loss did not improve from 0.00409
# Epoch 20/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0050 - val_loss: 0.0050
#
# Epoch 00020: val_loss did not improve from 0.00409
# Epoch 21/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0043
#
# Epoch 00021: val_loss did not improve from 0.00409
# Epoch 22/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0042
#
# Epoch 00022: val_loss did not improve from 0.00409
# Epoch 23/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0051
#
# Epoch 00023: val_loss did not improve from 0.00409
# Epoch 24/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0049 - val_loss: 0.0049
#
# Epoch 00024: val_loss did not improve from 0.00409
# Epoch 25/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0065
#
# Epoch 00025: val_loss did not improve from 0.00409
# Epoch 26/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0052 - val_loss: 0.0042
#
# Epoch 00026: val_loss did not improve from 0.00409
# Epoch 27/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0040
#
# Epoch 00027: val_loss improved from 0.00409 to 0.00403, saving model to results/univariate_LSTM\rnn.h5
# Epoch 28/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0040
#
# Epoch 00028: val_loss improved from 0.00403 to 0.00400, saving model to results/univariate_LSTM\rnn.h5
# Epoch 29/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0041
#
# Epoch 00029: val_loss did not improve from 0.00400
# Epoch 30/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0043 - val_loss: 0.0052
#
# Epoch 00030: val_loss did not improve from 0.00400
# Epoch 31/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0076
#
# Epoch 00031: val_loss did not improve from 0.00400
# Epoch 32/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0049 - val_loss: 0.0040
#
# Epoch 00032: val_loss did not improve from 0.00400
# Epoch 33/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0058
#
# Epoch 00033: val_loss did not improve from 0.00400
# Epoch 34/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0050 - val_loss: 0.0043
#
# Epoch 00034: val_loss did not improve from 0.00400
# Epoch 35/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0046 - val_loss: 0.0057
#
# Epoch 00035: val_loss did not improve from 0.00400
# Epoch 36/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0053
#
# Epoch 00036: val_loss did not improve from 0.00400
# Epoch 37/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0043
#
# Epoch 00037: val_loss did not improve from 0.00400
# Epoch 38/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0040 - val_loss: 0.0040
#
# Epoch 00038: val_loss improved from 0.00400 to 0.00398, saving model to results/univariate_LSTM\rnn.h5
# Epoch 39/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0045
#
# Epoch 00039: val_loss did not improve from 0.00398
# Epoch 40/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00040: val_loss did not improve from 0.00398
# Epoch 41/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0040
#
# Epoch 00041: val_loss did not improve from 0.00398
# Epoch 42/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0042 - val_loss: 0.0041
#
# Epoch 00042: val_loss did not improve from 0.00398
# Epoch 43/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0042 - val_loss: 0.0053
#
# Epoch 00043: val_loss did not improve from 0.00398
# Epoch 44/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0047
#
# Epoch 00044: val_loss did not improve from 0.00398
# Epoch 45/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0043
#
# Epoch 00045: val_loss did not improve from 0.00398
# Epoch 46/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0043 - val_loss: 0.0046
#
# Epoch 00046: val_loss did not improve from 0.00398
# Epoch 47/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0043 - val_loss: 0.0042
#
# Epoch 00047: val_loss did not improve from 0.00398
# Epoch 48/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0049
#
# Epoch 00048: val_loss did not improve from 0.00398
# Epoch 49/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0043
#
# Epoch 00049: val_loss did not improve from 0.00398
# Epoch 50/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0049
#
# Epoch 00050: val_loss did not improve from 0.00398
# Epoch 51/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0047
#
# Epoch 00051: val_loss did not improve from 0.00398
# Epoch 52/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0045 - val_loss: 0.0040
#
# Epoch 00052: val_loss did not improve from 0.00398
# Epoch 53/150
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0048 - val_loss: 0.0048
#
# Epoch 00053: val_loss did not improve from 0.00398
# Epoch 54/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0040
#
# Epoch 00054: val_loss improved from 0.00398 to 0.00398, saving model to results/univariate_LSTM\rnn.h5
# Epoch 55/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0045 - val_loss: 0.0040
#
# Epoch 00055: val_loss did not improve from 0.00398
# Epoch 56/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0043
#
# Epoch 00056: val_loss did not improve from 0.00398
# Epoch 57/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0051 - val_loss: 0.0046
#
# Epoch 00057: val_loss did not improve from 0.00398
# Epoch 58/150
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: 0.0043
#
# Epoch 00058: val_loss did not improve from 0.00398
# Epoch 59/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0042 - val_loss: 0.0050
#
# Epoch 00059: val_loss did not improve from 0.00398
# Epoch 60/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0041
#
# Epoch 00060: val_loss did not improve from 0.00398
# Epoch 61/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0049
#
# Epoch 00061: val_loss did not improve from 0.00398
# Epoch 62/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0042
#
# Epoch 00062: val_loss did not improve from 0.00398
# Epoch 63/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0040
#
# Epoch 00063: val_loss improved from 0.00398 to 0.00398, saving model to results/univariate_LSTM\rnn.h5
# Epoch 64/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0045
#
# Epoch 00064: val_loss did not improve from 0.00398
# Epoch 65/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0056
#
# Epoch 00065: val_loss did not improve from 0.00398
# Epoch 66/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0049 - val_loss: 0.0040
#
# Epoch 00066: val_loss did not improve from 0.00398
# Epoch 67/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0041
#
# Epoch 00067: val_loss did not improve from 0.00398
# Epoch 68/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.0040
#
# Epoch 00068: val_loss did not improve from 0.00398
# Epoch 69/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0046
#
# Epoch 00069: val_loss did not improve from 0.00398
# Epoch 70/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0045
#
# Epoch 00070: val_loss did not improve from 0.00398
# Epoch 71/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0049
#
# Epoch 00071: val_loss did not improve from 0.00398
# Epoch 72/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0049 - val_loss: 0.0041
#
# Epoch 00072: val_loss did not improve from 0.00398
# Epoch 73/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0040
#
# Epoch 00073: val_loss improved from 0.00398 to 0.00397, saving model to results/univariate_LSTM\rnn.h5
# Epoch 74/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0040
#
# Epoch 00074: val_loss did not improve from 0.00397
# Epoch 75/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0046
#
# Epoch 00075: val_loss did not improve from 0.00397
# Epoch 76/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00076: val_loss improved from 0.00397 to 0.00396, saving model to results/univariate_LSTM\rnn.h5
# Epoch 77/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0044 - val_loss: 0.0046
#
# Epoch 00077: val_loss did not improve from 0.00396
# Epoch 78/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0044 - val_loss: 0.0041
#
# Epoch 00078: val_loss did not improve from 0.00396
# Epoch 79/150
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0041 - val_loss: 0.0042
#
# Epoch 00079: val_loss did not improve from 0.00396
# Epoch 80/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0048 - val_loss: 0.0048
#
# Epoch 00080: val_loss did not improve from 0.00396
# Epoch 81/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0041
#
# Epoch 00081: val_loss did not improve from 0.00396
# Epoch 82/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0040
#
# Epoch 00082: val_loss did not improve from 0.00396
# Epoch 83/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0046 - val_loss: 0.0042
#
# Epoch 00083: val_loss did not improve from 0.00396
# Epoch 84/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.0058
#
# Epoch 00084: val_loss did not improve from 0.00396
# Epoch 85/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0046 - val_loss: 0.0041
#
# Epoch 00085: val_loss did not improve from 0.00396
# Epoch 86/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0060
#
# Epoch 00086: val_loss did not improve from 0.00396
# Epoch 87/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0049
#
# Epoch 00087: val_loss did not improve from 0.00396
# Epoch 88/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0043 - val_loss: 0.0042
#
# Epoch 00088: val_loss did not improve from 0.00396
# Epoch 89/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0041
#
# Epoch 00089: val_loss did not improve from 0.00396
# Epoch 90/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0041
#
# Epoch 00090: val_loss did not improve from 0.00396
# Epoch 91/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.0047
#
# Epoch 00091: val_loss did not improve from 0.00396
# Epoch 92/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0040
#
# Epoch 00092: val_loss did not improve from 0.00396
# Epoch 93/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0044
#
# Epoch 00093: val_loss did not improve from 0.00396
# Epoch 94/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0042 - val_loss: 0.0043
#
# Epoch 00094: val_loss did not improve from 0.00396
# Epoch 95/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00095: val_loss did not improve from 0.00396
# Epoch 96/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0045
#
# Epoch 00096: val_loss did not improve from 0.00396
# Test accuracy: 0.67
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                            XMR
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/150
# 51/51 [==============================] - 3s 19ms/step - loss: 0.0922 - val_loss: 0.0062
#
# Epoch 00001: val_loss improved from inf to 0.00620, saving model to results/univariate_LSTM\rnn.h5
# Epoch 2/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0057 - val_loss: 0.0030
#
# Epoch 00002: val_loss improved from 0.00620 to 0.00302, saving model to results/univariate_LSTM\rnn.h5
# Epoch 3/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0035
#
# Epoch 00003: val_loss did not improve from 0.00302
# Epoch 4/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0037
#
# Epoch 00004: val_loss did not improve from 0.00302
# Epoch 5/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0056 - val_loss: 0.0030
#
# Epoch 00005: val_loss did not improve from 0.00302
# Epoch 6/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0054 - val_loss: 0.0040
#
# Epoch 00006: val_loss did not improve from 0.00302
# Epoch 7/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0062 - val_loss: 0.0035
#
# Epoch 00007: val_loss did not improve from 0.00302
# Epoch 8/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0032
#
# Epoch 00008: val_loss did not improve from 0.00302
# Epoch 9/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0037
#
# Epoch 00009: val_loss did not improve from 0.00302
# Epoch 10/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0054 - val_loss: 0.0034
#
# Epoch 00010: val_loss did not improve from 0.00302
# Epoch 11/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0030
#
# Epoch 00011: val_loss improved from 0.00302 to 0.00299, saving model to results/univariate_LSTM\rnn.h5
# Epoch 12/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0077
#
# Epoch 00012: val_loss did not improve from 0.00299
# Epoch 13/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0029
#
# Epoch 00013: val_loss improved from 0.00299 to 0.00294, saving model to results/univariate_LSTM\rnn.h5
# Epoch 14/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0035
#
# Epoch 00014: val_loss did not improve from 0.00294
# Epoch 15/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0059
#
# Epoch 00015: val_loss did not improve from 0.00294
# Epoch 16/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0054 - val_loss: 0.0046
#
# Epoch 00016: val_loss did not improve from 0.00294
# Epoch 17/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0052 - val_loss: 0.0059
#
# Epoch 00017: val_loss did not improve from 0.00294
# Epoch 18/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0051 - val_loss: 0.0030
#
# Epoch 00018: val_loss did not improve from 0.00294
# Epoch 19/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0031
#
# Epoch 00019: val_loss did not improve from 0.00294
# Epoch 20/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0047
#
# Epoch 00020: val_loss did not improve from 0.00294
# Epoch 21/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0056 - val_loss: 0.0029
#
# Epoch 00021: val_loss improved from 0.00294 to 0.00289, saving model to results/univariate_LSTM\rnn.h5
# Epoch 22/150
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0050 - val_loss: 0.0029
#
# Epoch 00022: val_loss improved from 0.00289 to 0.00287, saving model to results/univariate_LSTM\rnn.h5
# Epoch 23/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0032
#
# Epoch 00023: val_loss did not improve from 0.00287
# Epoch 24/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 00024: val_loss did not improve from 0.00287
# Epoch 25/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0055 - val_loss: 0.0057
#
# Epoch 00025: val_loss did not improve from 0.00287
# Epoch 26/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0076
#
# Epoch 00026: val_loss did not improve from 0.00287
# Epoch 27/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0056 - val_loss: 0.0030
#
# Epoch 00027: val_loss did not improve from 0.00287
# Epoch 28/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0029
#
# Epoch 00028: val_loss did not improve from 0.00287
# Epoch 29/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0042
#
# Epoch 00029: val_loss did not improve from 0.00287
# Epoch 30/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0029
#
# Epoch 00030: val_loss did not improve from 0.00287
# Epoch 31/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0031
#
# Epoch 00031: val_loss did not improve from 0.00287
# Epoch 32/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0059
#
# Epoch 00032: val_loss did not improve from 0.00287
# Epoch 33/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0028
#
# Epoch 00033: val_loss improved from 0.00287 to 0.00282, saving model to results/univariate_LSTM\rnn.h5
# Epoch 34/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0031
#
# Epoch 00034: val_loss did not improve from 0.00282
# Epoch 35/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0055 - val_loss: 0.0034
#
# Epoch 00035: val_loss did not improve from 0.00282
# Epoch 36/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0058 - val_loss: 0.0039
#
# Epoch 00036: val_loss did not improve from 0.00282
# Epoch 37/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0057 - val_loss: 0.0028
#
# Epoch 00037: val_loss improved from 0.00282 to 0.00277, saving model to results/univariate_LSTM\rnn.h5
# Epoch 38/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0028
#
# Epoch 00038: val_loss did not improve from 0.00277
# Epoch 39/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0053 - val_loss: 0.0035
#
# Epoch 00039: val_loss did not improve from 0.00277
# Epoch 40/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0046
#
# Epoch 00040: val_loss did not improve from 0.00277
# Epoch 41/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0053 - val_loss: 0.0032
#
# Epoch 00041: val_loss did not improve from 0.00277
# Epoch 42/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0041
#
# Epoch 00042: val_loss did not improve from 0.00277
# Epoch 43/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0040 - val_loss: 0.0053
#
# Epoch 00043: val_loss did not improve from 0.00277
# Epoch 44/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0029
#
# Epoch 00044: val_loss did not improve from 0.00277
# Epoch 45/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0030
#
# Epoch 00045: val_loss did not improve from 0.00277
# Epoch 46/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0035
#
# Epoch 00046: val_loss did not improve from 0.00277
# Epoch 47/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0032
#
# Epoch 00047: val_loss did not improve from 0.00277
# Epoch 48/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0041
#
# Epoch 00048: val_loss did not improve from 0.00277
# Epoch 49/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0033
#
# Epoch 00049: val_loss did not improve from 0.00277
# Epoch 50/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0028
#
# Epoch 00050: val_loss improved from 0.00277 to 0.00277, saving model to results/univariate_LSTM\rnn.h5
# Epoch 51/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0028
#
# Epoch 00051: val_loss did not improve from 0.00277
# Epoch 52/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0044 - val_loss: 0.0034
#
# Epoch 00052: val_loss did not improve from 0.00277
# Epoch 53/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0030
#
# Epoch 00053: val_loss did not improve from 0.00277
# Epoch 54/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0028
#
# Epoch 00054: val_loss improved from 0.00277 to 0.00276, saving model to results/univariate_LSTM\rnn.h5
# Epoch 55/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0050 - val_loss: 0.0028
#
# Epoch 00055: val_loss improved from 0.00276 to 0.00275, saving model to results/univariate_LSTM\rnn.h5
# Epoch 56/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0043
#
# Epoch 00056: val_loss did not improve from 0.00275
# Epoch 57/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0031
#
# Epoch 00057: val_loss did not improve from 0.00275
# Epoch 58/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0030
#
# Epoch 00058: val_loss did not improve from 0.00275
# Epoch 59/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0040 - val_loss: 0.0046
#
# Epoch 00059: val_loss did not improve from 0.00275
# Epoch 60/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0038
#
# Epoch 00060: val_loss did not improve from 0.00275
# Epoch 61/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0035
#
# Epoch 00061: val_loss did not improve from 0.00275
# Epoch 62/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0030
#
# Epoch 00062: val_loss did not improve from 0.00275
# Epoch 63/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0046 - val_loss: 0.0037
#
# Epoch 00063: val_loss did not improve from 0.00275
# Epoch 64/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0046 - val_loss: 0.0027
#
# Epoch 00064: val_loss improved from 0.00275 to 0.00275, saving model to results/univariate_LSTM\rnn.h5
# Epoch 65/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0030
#
# Epoch 00065: val_loss did not improve from 0.00275
# Epoch 66/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0032
#
# Epoch 00066: val_loss did not improve from 0.00275
# Epoch 67/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0055 - val_loss: 0.0032
#
# Epoch 00067: val_loss did not improve from 0.00275
# Epoch 68/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0030
#
# Epoch 00068: val_loss did not improve from 0.00275
# Epoch 69/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0041 - val_loss: 0.0037
#
# Epoch 00069: val_loss did not improve from 0.00275
# Epoch 70/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0028
#
# Epoch 00070: val_loss did not improve from 0.00275
# Epoch 71/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0035
#
# Epoch 00071: val_loss did not improve from 0.00275
# Epoch 72/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0028
#
# Epoch 00072: val_loss did not improve from 0.00275
# Epoch 73/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0056
#
# Epoch 00073: val_loss did not improve from 0.00275
# Epoch 74/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0048 - val_loss: 0.0027
#
# Epoch 00074: val_loss improved from 0.00275 to 0.00275, saving model to results/univariate_LSTM\rnn.h5
# Epoch 75/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0052 - val_loss: 0.0042
#
# Epoch 00075: val_loss did not improve from 0.00275
# Epoch 76/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0058 - val_loss: 0.0030
#
# Epoch 00076: val_loss did not improve from 0.00275
# Epoch 77/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0028
#
# Epoch 00077: val_loss did not improve from 0.00275
# Epoch 78/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0030
#
# Epoch 00078: val_loss did not improve from 0.00275
# Epoch 79/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0034
#
# Epoch 00079: val_loss did not improve from 0.00275
# Epoch 80/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0042 - val_loss: 0.0029
#
# Epoch 00080: val_loss did not improve from 0.00275
# Epoch 81/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0049 - val_loss: 0.0031
#
# Epoch 00081: val_loss did not improve from 0.00275
# Epoch 82/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0039
#
# Epoch 00082: val_loss did not improve from 0.00275
# Epoch 83/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0031
#
# Epoch 00083: val_loss did not improve from 0.00275
# Epoch 84/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0042
#
# Epoch 00084: val_loss did not improve from 0.00275
# Epoch 85/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0039
#
# Epoch 00085: val_loss did not improve from 0.00275
# Epoch 86/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0032
#
# Epoch 00086: val_loss did not improve from 0.00275
# Epoch 87/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0028
#
# Epoch 00087: val_loss did not improve from 0.00275
# Epoch 88/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0028
#
# Epoch 00088: val_loss did not improve from 0.00275
# Epoch 89/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0033
#
# Epoch 00089: val_loss did not improve from 0.00275
# Epoch 90/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0029
#
# Epoch 00090: val_loss did not improve from 0.00275
# Epoch 91/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0028
#
# Epoch 00091: val_loss did not improve from 0.00275
# Epoch 92/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0054 - val_loss: 0.0028
#
# Epoch 00092: val_loss did not improve from 0.00275
# Epoch 93/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0029
#
# Epoch 00093: val_loss did not improve from 0.00275
# Epoch 94/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0041 - val_loss: 0.0027
#
# Epoch 00094: val_loss improved from 0.00275 to 0.00273, saving model to results/univariate_LSTM\rnn.h5
# Epoch 95/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0045
#
# Epoch 00095: val_loss did not improve from 0.00273
# Epoch 96/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0027
#
# Epoch 00096: val_loss did not improve from 0.00273
# Epoch 97/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0043 - val_loss: 0.0036
#
# Epoch 00097: val_loss did not improve from 0.00273
# Epoch 98/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0044 - val_loss: 0.0028
#
# Epoch 00098: val_loss did not improve from 0.00273
# Epoch 99/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0048 - val_loss: 0.0029
#
# Epoch 00099: val_loss did not improve from 0.00273
# Epoch 100/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0050 - val_loss: 0.0028
#
# Epoch 00100: val_loss did not improve from 0.00273
# Epoch 101/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0052 - val_loss: 0.0027
#
# Epoch 00101: val_loss did not improve from 0.00273
# Epoch 102/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0046 - val_loss: 0.0036
#
# Epoch 00102: val_loss did not improve from 0.00273
# Epoch 103/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0031
#
# Epoch 00103: val_loss did not improve from 0.00273
# Epoch 104/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0038
#
# Epoch 00104: val_loss did not improve from 0.00273
# Epoch 105/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0028
#
# Epoch 00105: val_loss did not improve from 0.00273
# Epoch 106/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0035
#
# Epoch 00106: val_loss did not improve from 0.00273
# Epoch 107/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0027
#
# Epoch 00107: val_loss improved from 0.00273 to 0.00272, saving model to results/univariate_LSTM\rnn.h5
# Epoch 108/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0042 - val_loss: 0.0042
#
# Epoch 00108: val_loss did not improve from 0.00272
# Epoch 109/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0034
#
# Epoch 00109: val_loss did not improve from 0.00272
# Epoch 110/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0029
#
# Epoch 00110: val_loss did not improve from 0.00272
# Epoch 111/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0034
#
# Epoch 00111: val_loss did not improve from 0.00272
# Epoch 112/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0044 - val_loss: 0.0038
#
# Epoch 00112: val_loss did not improve from 0.00272
# Epoch 113/150
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0047 - val_loss: 0.0028
#
# Epoch 00113: val_loss did not improve from 0.00272
# Epoch 114/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0045 - val_loss: 0.0035
#
# Epoch 00114: val_loss did not improve from 0.00272
# Epoch 115/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0041 - val_loss: 0.0027
#
# Epoch 00115: val_loss did not improve from 0.00272
# Epoch 116/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0030
#
# Epoch 00116: val_loss did not improve from 0.00272
# Epoch 117/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0053
#
# Epoch 00117: val_loss did not improve from 0.00272
# Epoch 118/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0049 - val_loss: 0.0029
#
# Epoch 00118: val_loss did not improve from 0.00272
# Epoch 119/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0034
#
# Epoch 00119: val_loss did not improve from 0.00272
# Epoch 120/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0029
#
# Epoch 00120: val_loss did not improve from 0.00272
# Epoch 121/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0027
#
# Epoch 00121: val_loss did not improve from 0.00272
# Epoch 122/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0047 - val_loss: 0.0029
#
# Epoch 00122: val_loss did not improve from 0.00272
# Epoch 123/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0043 - val_loss: 0.0028
#
# Epoch 00123: val_loss did not improve from 0.00272
# Epoch 124/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0048 - val_loss: 0.0036
#
# Epoch 00124: val_loss did not improve from 0.00272
# Epoch 125/150
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0044 - val_loss: 0.0029
#
# Epoch 00125: val_loss did not improve from 0.00272
# Epoch 126/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0053 - val_loss: 0.0028
#
# Epoch 00126: val_loss did not improve from 0.00272
# Epoch 127/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0044 - val_loss: 0.0031
#
# Epoch 00127: val_loss did not improve from 0.00272
# Test accuracy: 0.67
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                            ETC
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/150
# 51/51 [==============================] - 3s 20ms/step - loss: 0.0650 - val_loss: 0.0034
#
# Epoch 00001: val_loss improved from inf to 0.00336, saving model to results/univariate_LSTM\rnn.h5
# Epoch 2/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0080
#
# Epoch 00002: val_loss did not improve from 0.00336
# Epoch 3/150
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0061 - val_loss: 0.0037
#
# Epoch 00003: val_loss did not improve from 0.00336
# Epoch 4/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0052 - val_loss: 0.0044
#
# Epoch 00004: val_loss did not improve from 0.00336
# Epoch 5/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0064 - val_loss: 0.0051
#
# Epoch 00005: val_loss did not improve from 0.00336
# Epoch 6/150
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0054 - val_loss: 0.0036
#
# Epoch 00006: val_loss did not improve from 0.00336
# Epoch 7/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0040
#
# Epoch 00007: val_loss did not improve from 0.00336
# Epoch 8/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0062 - val_loss: 0.0108
#
# Epoch 00008: val_loss did not improve from 0.00336
# Epoch 9/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0061 - val_loss: 0.0034
#
# Epoch 00009: val_loss did not improve from 0.00336
# Epoch 10/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0046 - val_loss: 0.0033
#
# Epoch 00010: val_loss improved from 0.00336 to 0.00326, saving model to results/univariate_LSTM\rnn.h5
# Epoch 11/150
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0054 - val_loss: 0.0038
#
# Epoch 00011: val_loss did not improve from 0.00326
# Epoch 12/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0067
#
# Epoch 00012: val_loss did not improve from 0.00326
# Epoch 13/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0052 - val_loss: 0.0051
#
# Epoch 00013: val_loss did not improve from 0.00326
# Epoch 14/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0048
#
# Epoch 00014: val_loss did not improve from 0.00326
# Epoch 15/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0032
#
# Epoch 00015: val_loss improved from 0.00326 to 0.00324, saving model to results/univariate_LSTM\rnn.h5
# Epoch 16/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0048 - val_loss: 0.0047
#
# Epoch 00016: val_loss did not improve from 0.00324
# Epoch 17/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0038
#
# Epoch 00017: val_loss did not improve from 0.00324
# Epoch 18/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0041
#
# Epoch 00018: val_loss did not improve from 0.00324
# Epoch 19/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0047 - val_loss: 0.0033
#
# Epoch 00019: val_loss did not improve from 0.00324
# Epoch 20/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0056 - val_loss: 0.0080
#
# Epoch 00020: val_loss did not improve from 0.00324
# Epoch 21/150
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0047 - val_loss: 0.0032
#
# Epoch 00021: val_loss improved from 0.00324 to 0.00324, saving model to results/univariate_LSTM\rnn.h5
# Epoch 22/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0052 - val_loss: 0.0035
#
# Epoch 00022: val_loss did not improve from 0.00324
# Epoch 23/150
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0049 - val_loss: 0.0036
#
# Epoch 00023: val_loss did not improve from 0.00324
# Epoch 24/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0046 - val_loss: 0.0048
#
# Epoch 00024: val_loss did not improve from 0.00324
# Epoch 25/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0033
#
# Epoch 00025: val_loss did not improve from 0.00324
# Epoch 26/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0033
#
# Epoch 00026: val_loss did not improve from 0.00324
# Epoch 27/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0034
#
# Epoch 00027: val_loss did not improve from 0.00324
# Epoch 28/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0046
#
# Epoch 00028: val_loss did not improve from 0.00324
# Epoch 29/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0041
#
# Epoch 00029: val_loss did not improve from 0.00324
# Epoch 30/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0032
#
# Epoch 00030: val_loss did not improve from 0.00324
# Epoch 31/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0043
#
# Epoch 00031: val_loss did not improve from 0.00324
# Epoch 32/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0061 - val_loss: 0.0062
#
# Epoch 00032: val_loss did not improve from 0.00324
# Epoch 33/150
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0050 - val_loss: 0.0034
#
# Epoch 00033: val_loss did not improve from 0.00324
# Epoch 34/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0063
#
# Epoch 00034: val_loss did not improve from 0.00324
# Epoch 35/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0058 - val_loss: 0.0033
#
# Epoch 00035: val_loss did not improve from 0.00324
# Epoch 36/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0050
#
# Epoch 00036: val_loss did not improve from 0.00324
# Epoch 37/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0039
#
# Epoch 00037: val_loss did not improve from 0.00324
# Epoch 38/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0054 - val_loss: 0.0051
#
# Epoch 00038: val_loss did not improve from 0.00324
# Epoch 39/150
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0055 - val_loss: 0.0034
#
# Epoch 00039: val_loss did not improve from 0.00324
# Epoch 40/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0041
#
# Epoch 00040: val_loss did not improve from 0.00324
# Epoch 41/150
# ...
#
# Epoch 00064: val_loss did not improve from 0.00304
# Epoch 65/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0042 - val_loss: 0.0031
#
# Epoch 00065: val_loss did not improve from 0.00304
# Epoch 66/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0034
#
# Epoch 00066: val_loss did not improve from 0.00304
# Epoch 67/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0031
#
# Epoch 00067: val_loss did not improve from 0.00304
# Epoch 68/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0035
#
# Epoch 00068: val_loss did not improve from 0.00304
# Epoch 69/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0031
#
# Epoch 00069: val_loss did not improve from 0.00304
# Epoch 70/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0031
#
# Epoch 00070: val_loss did not improve from 0.00304
# Epoch 71/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0033
#
# Epoch 00071: val_loss did not improve from 0.00304
# Epoch 72/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0037
#
# Epoch 00072: val_loss did not improve from 0.00304
# Epoch 73/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0032
#
# Epoch 00073: val_loss did not improve from 0.00304
# Epoch 74/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0032
#
# Epoch 00074: val_loss did not improve from 0.00304
# Epoch 75/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0042 - val_loss: 0.0031
#
# Epoch 00075: val_loss did not improve from 0.00304
# Epoch 76/150
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0030
#
# Epoch 00076: val_loss did not improve from 0.00304
# Test accuracy: 0.60
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                            BNB
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/150
# 40/40 [==============================] - 3s 22ms/step - loss: 0.0702 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00192, saving model to results/univariate_LSTM\rnn.h5
# Epoch 2/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 0.0019
#
# Epoch 00002: val_loss did not improve from 0.00192
# Epoch 3/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0031 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00192 to 0.00192, saving model to results/univariate_LSTM\rnn.h5
# Epoch 4/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00192 to 0.00190, saving model to results/univariate_LSTM\rnn.h5
# Epoch 5/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0028 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00190
# Epoch 6/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0025
#
# Epoch 00006: val_loss did not improve from 0.00190
# Epoch 7/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 0.0020
#
# Epoch 00007: val_loss did not improve from 0.00190
# Epoch 8/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0020
#
# Epoch 00008: val_loss did not improve from 0.00190
# Epoch 9/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0021
#
# Epoch 00009: val_loss did not improve from 0.00190
# Epoch 10/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0021
#
# Epoch 00010: val_loss did not improve from 0.00190
# Epoch 11/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 0.0020
#
# Epoch 00011: val_loss did not improve from 0.00190
# Epoch 12/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0024 - val_loss: 0.0021
#
# Epoch 00012: val_loss did not improve from 0.00190
# Epoch 13/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0019
#
# Epoch 00013: val_loss improved from 0.00190 to 0.00186, saving model to results/univariate_LSTM\rnn.h5
# Epoch 14/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0030 - val_loss: 0.0024
#
# Epoch 00014: val_loss did not improve from 0.00186
# Epoch 15/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0021
#
# Epoch 00015: val_loss did not improve from 0.00186
# Epoch 16/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0019
#
# Epoch 00016: val_loss improved from 0.00186 to 0.00186, saving model to results/univariate_LSTM\rnn.h5
# Epoch 17/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0032 - val_loss: 0.0020
#
# Epoch 00017: val_loss did not improve from 0.00186
# Epoch 18/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0019
#
# Epoch 00018: val_loss improved from 0.00186 to 0.00185, saving model to results/univariate_LSTM\rnn.h5
# Epoch 19/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0028
#
# Epoch 00019: val_loss did not improve from 0.00185
# Epoch 20/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0019
#
# Epoch 00020: val_loss did not improve from 0.00185
# Epoch 21/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0020
#
# Epoch 00021: val_loss did not improve from 0.00185
# Epoch 22/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0019
#
# Epoch 00022: val_loss did not improve from 0.00185
# Epoch 23/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0021
#
# Epoch 00023: val_loss did not improve from 0.00185
# Epoch 24/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0024 - val_loss: 0.0018
#
# Epoch 00024: val_loss improved from 0.00185 to 0.00184, saving model to results/univariate_LSTM\rnn.h5
# Epoch 25/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0018
#
# Epoch 00025: val_loss did not improve from 0.00184
# Epoch 26/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0019
#
# Epoch 00026: val_loss did not improve from 0.00184
# Epoch 27/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0020
#
# Epoch 00027: val_loss did not improve from 0.00184
# Epoch 28/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0018
#
# Epoch 00028: val_loss improved from 0.00184 to 0.00183, saving model to results/univariate_LSTM\rnn.h5
# Epoch 29/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0019
#
# Epoch 00029: val_loss did not improve from 0.00183
# Epoch 30/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0019
#
# Epoch 00030: val_loss did not improve from 0.00183
# Epoch 31/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0018
#
# Epoch 00031: val_loss did not improve from 0.00183
# Epoch 32/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 0.0019
#
# Epoch 00032: val_loss did not improve from 0.00183
# Epoch 33/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0024 - val_loss: 0.0018
#
# Epoch 00033: val_loss did not improve from 0.00183
# Epoch 34/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0018
#
# Epoch 00034: val_loss did not improve from 0.00183
# Epoch 35/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0030 - val_loss: 0.0020
#
# Epoch 00035: val_loss did not improve from 0.00183
# Epoch 36/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0018
#
# Epoch 00036: val_loss did not improve from 0.00183
# Epoch 37/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0019
#
# Epoch 00037: val_loss did not improve from 0.00183
# Epoch 38/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 0.0019
#
# Epoch 00038: val_loss did not improve from 0.00183
# Epoch 39/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0019
#
# Epoch 00039: val_loss did not improve from 0.00183
# Epoch 40/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0019
#
# Epoch 00040: val_loss did not improve from 0.00183
# Epoch 41/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0019
#
# Epoch 00041: val_loss did not improve from 0.00183
# Epoch 42/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0032 - val_loss: 0.0021
#
# Epoch 00042: val_loss did not improve from 0.00183
# Epoch 43/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0019
#
# Epoch 00043: val_loss did not improve from 0.00183
# Epoch 44/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0018
#
# Epoch 00044: val_loss did not improve from 0.00183
# Epoch 45/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0018
#
# Epoch 00045: val_loss improved from 0.00183 to 0.00183, saving model to results/univariate_LSTM\rnn.h5
# Epoch 46/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0019
#
# Epoch 00046: val_loss did not improve from 0.00183
# Epoch 47/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0024 - val_loss: 0.0018
#
# Epoch 00047: val_loss improved from 0.00183 to 0.00183, saving model to results/univariate_LSTM\rnn.h5
# Epoch 48/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0019
#
# Epoch 00048: val_loss did not improve from 0.00183
# Epoch 49/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0019
#
# Epoch 00049: val_loss did not improve from 0.00183
# Epoch 50/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0031 - val_loss: 0.0019
#
# Epoch 00050: val_loss did not improve from 0.00183
# Epoch 51/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0019
#
# Epoch 00051: val_loss did not improve from 0.00183
# Epoch 52/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0026
#
# Epoch 00052: val_loss did not improve from 0.00183
# Epoch 53/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0018
#
# Epoch 00053: val_loss did not improve from 0.00183
# Epoch 54/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0021
#
# Epoch 00054: val_loss did not improve from 0.00183
# Epoch 55/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0018
#
# Epoch 00055: val_loss improved from 0.00183 to 0.00182, saving model to results/univariate_LSTM\rnn.h5
# Epoch 56/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0019
#
# Epoch 00056: val_loss did not improve from 0.00182
# Epoch 57/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0024 - val_loss: 0.0018
#
# Epoch 00057: val_loss did not improve from 0.00182
# Epoch 58/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 0.0019
#
# Epoch 00058: val_loss did not improve from 0.00182
# Epoch 59/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0022
#
# Epoch 00059: val_loss did not improve from 0.00182
# Epoch 60/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0020
#
# Epoch 00060: val_loss did not improve from 0.00182
# Epoch 61/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0019
#
# Epoch 00061: val_loss did not improve from 0.00182
# Epoch 62/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0018
#
# Epoch 00062: val_loss did not improve from 0.00182
# Epoch 63/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0018
#
# Epoch 00063: val_loss improved from 0.00182 to 0.00182, saving model to results/univariate_LSTM\rnn.h5
# Epoch 64/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0018
#
# Epoch 00064: val_loss did not improve from 0.00182
# Epoch 65/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0018
#
# Epoch 00065: val_loss did not improve from 0.00182
# Epoch 66/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 0.0020
#
# Epoch 00066: val_loss did not improve from 0.00182
# Epoch 67/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0019
#
# Epoch 00067: val_loss did not improve from 0.00182
# Epoch 68/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 0.0018
#
# Epoch 00068: val_loss did not improve from 0.00182
# Epoch 69/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0019
#
# Epoch 00069: val_loss did not improve from 0.00182
# Epoch 70/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0018
#
# Epoch 00070: val_loss did not improve from 0.00182
# Epoch 71/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0022
#
# Epoch 00071: val_loss did not improve from 0.00182
# Epoch 72/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0021
#
# Epoch 00072: val_loss did not improve from 0.00182
# Epoch 73/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0028 - val_loss: 0.0020
#
# Epoch 00073: val_loss did not improve from 0.00182
# Epoch 74/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0018
#
# Epoch 00074: val_loss did not improve from 0.00182
# Epoch 75/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0021 - val_loss: 0.0024
#
# Epoch 00075: val_loss did not improve from 0.00182
# Epoch 76/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0019
#
# Epoch 00076: val_loss did not improve from 0.00182
# Epoch 77/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0018
#
# Epoch 00077: val_loss did not improve from 0.00182
# Epoch 78/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0018
#
# Epoch 00078: val_loss did not improve from 0.00182
# Epoch 79/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0018
#
# Epoch 00079: val_loss did not improve from 0.00182
# Epoch 80/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0018
#
# Epoch 00080: val_loss did not improve from 0.00182
# Epoch 81/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0018
#
# Epoch 00081: val_loss did not improve from 0.00182
# Epoch 82/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0018
#
# Epoch 00082: val_loss did not improve from 0.00182
# Epoch 83/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0031 - val_loss: 0.0018
#
# Epoch 00083: val_loss did not improve from 0.00182
# Test accuracy: 0.53

# %% [markdown]
# ### Train models left (top10 liquid CC)
# For now, we don't include top10 liquid CC

# %%
# for CC_name in list(set(top10CC_Liquid_test) - set(top10CC_MarketCap_test)):
#     exec(f"data_{CC_name} = train_model(CC_name)")

# %% [markdown]
# ### Fit the return of T+1 to into mean-variance model to get the optimal CC allocation

# %%
def find_top10CC_historical_returns(CC_name,CC_daily_data):
    dfclose = CC_daily_data[CC_daily_data['ticker']==(CC_name+'-USD')].set_index(['date'])['close'].to_frame()
    dfclose = dfclose[~dfclose.index.duplicated(keep = 'first')]
    dfreturn = (np.log(dfclose/dfclose.shift())
                .dropna()
                .rename(columns = {'close':CC_name}))
    return dfreturn

# %% [markdown]
# ### Only with long position

# %%
from pypfopt.efficient_frontier import EfficientFrontier
def find_optimal_weights_L(Returns,CovarianceMatrix):
    ef = EfficientFrontier(Returns, CovarianceMatrix, weight_bounds=(0,1))
    weights = ef.max_sharpe(risk_free_rate= 0.0)
    weights = ef.clean_weights()
    return weights

# %% [markdown]
# ### With long and short position

# %%
def find_optimal_weights_LS(Returns,CovarianceMatrix):
    ef = EfficientFrontier(Returns, CovarianceMatrix, weight_bounds=(-1,1))
    weights = ef.max_sharpe(risk_free_rate= 0.0)
    weights = ef.clean_weights()
    return weights

# %% [markdown]
# # Strategy with only long position
# # Need to test the conditions of that we don't hold any CC

# %%
TEST_START = '2020-01-01'
TEMP_DATE = '2020-03-25'
CC_daily_data=pd.read_csv('CC_daily_data.csv').dropna()
capital = 1
performance = pd.DataFrame(columns = ['Date','Actual_Return','Capital','Allocation','Top10CC_real_return'])

for date in top10CC.loc[TEST_START:].index:
    if date not in data_BTC.index:
        continue
    
    # Initialize variables
    top10CC_predicted_return = pd.DataFrame(columns = ['Ticker','Predicted_Return'])
    top10CC_historical_return = pd.DataFrame()
    
    # Get expected(predicted) returns on the "date", and the previous real returns before the date
    for  CC_name in ast.literal_eval(top10CC.loc[date]['top10_Market']):
        exec(f"return_temp = data_{CC_name}.loc[date]['predictions']")
        top10CC_predicted_return = top10CC_predicted_return.append({'Ticker':CC_name,'Predicted_Return':return_temp},ignore_index = True)
        top10CC_historical_return = pd.concat([top10CC_historical_return,find_top10CC_historical_returns(CC_name,CC_daily_data)],axis = 1).dropna()
        
    top10CC_predicted_return = top10CC_predicted_return.set_index('Ticker')
    top10CC_real_return = top10CC_historical_return.loc[date].to_frame()
    top10CC_historical_return = top10CC_historical_return.loc[:date][:-1]
    
    return_sum = weights = 0
    top10CC_predicted_return_temp = top10CC_predicted_return[top10CC_predicted_return>0].dropna()
    if len(top10CC_predicted_return_temp) > 4:  
        # Get the optimal weight of top10CC on the "date"
        weights = find_optimal_weights_L(top10CC_predicted_return['Predicted_Return'],top10CC_historical_return.cov())
        # Calcualte the real gain/loss on the "date"
        return_sum = (np.array(list(weights.values())).reshape(-1,1) * top10CC_real_return).sum()[0]
'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'BCH': 0....
# 1    {'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'BCH': 0....
# 2    {'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'BCH': 0....
# 3    {'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'BCH': 0....
# 4    {'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'BCH': 0....
# ..                                                 ...
# 355  {'BTC': 0.73929, 'ETH': 0.0, 'XRP': 0.0, 'LTC'...
# 356  {'BTC': 0.98635, 'ETH': 0.0, 'XRP': 0.0, 'LTC'...
# 357  {'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'LTC': 0....
# 358  {'BTC': 0.43617, 'ETH': 0.31873, 'XRP': 0.0, '...
# 359  {'BTC': 0.18836, 'ETH': 0.12741, 'XRP': 0.0, '...
#
#                                    Top10CC_real_return
# 0         2020-01-01
# BTC    0.000914
# ETH    0.00914...
# 1         2020-01-02
# BTC   -0.030273
# ETH   -0.02627...
# 2         2020-01-03
# BTC    0.050172
# ETH    0.05170...
# 3         2020-01-04
# BTC    0.008915
# ETH    0.00666...
# 4         2020-01-05
# BTC    0.000089
# ETH    0.00889...
# ..                                                 ...
# 355        2020-12-26
# BTC     0.069389
# ETH     0.01...
# 356        2020-12-27
# BTC    -0.006251
# ETH     0.07...
# 357        2020-12-28
# BTC     0.030458
# ETH     0.06...
# 358        2020-12-29
# BTC     0.010198
# ETH     0.00...
# 359        2020-12-30
# BTC     0.052625
# ETH     0.02...
#
# [360 rows x 5 columns]

# %%
result = pd.concat([performance.set_index('Date'), CC100_Index], axis = 1).dropna()
result
# Out:
#             Actual_Return   Capital  \
# 2020-01-01       0.006545  1.006545
# 2020-01-02      -0.050903  0.955309
# 2020-01-03       0.105212  1.055819
# 2020-01-04       0.015946  1.072655
# 2020-01-05       0.045079  1.121009
# ...                   ...       ...
# 2020-12-26       0.056332  6.419769
# 2020-12-27      -0.004788  6.389034
# 2020-12-28       0.057028  6.753389
# 2020-12-29       0.025320  6.924386
# 2020-12-30      -0.006256  6.881064
#
#                                                    Allocation  \
# 2020-01-01  {'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'BCH': 0....
# 2020-01-02  {'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'BCH': 0....
# 2020-01-03  {'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'BCH': 0....
# 2020-01-04  {'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'BCH': 0....
# 2020-01-05  {'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'BCH': 0....
# ...                                                       ...
# 2020-12-26  {'BTC': 0.73929, 'ETH': 0.0, 'XRP': 0.0, 'LTC'...
# 2020-12-27  {'BTC': 0.98635, 'ETH': 0.0, 'XRP': 0.0, 'LTC'...
# 2020-12-28  {'BTC': 0.0, 'ETH': 0.0, 'XRP': 0.0, 'LTC': 0....
# 2020-12-29  {'BTC': 0.43617, 'ETH': 0.31873, 'XRP': 0.0, '...
# 2020-12-30  {'BTC': 0.18836, 'ETH': 0.12741, 'XRP': 0.0, '...
#
#                                           Top10CC_real_return  MarketIndex  \
# 2020-01-01       2020-01-01
# BTC    0.000914
# ETH    0.00914...      7068.77
# 2020-01-02       2020-01-02
# BTC   -0.030273
# ETH   -0.02627...      6778.93
# 2020-01-03       2020-01-03
# BTC    0.050172
# ETH    0.05170...      7152.82
# 2020-01-04       2020-01-04
# BTC    0.008915
# ETH    0.00666...      7177.27
# 2020-01-05       2020-01-05
# BTC    0.000089
# ETH    0.00889...      7296.59
# ...                                                       ...          ...
# 2020-12-26        2020-12-26
# BTC     0.069389
# ETH     0.01...     24145.53
# 2020-12-27        2020-12-27
# BTC    -0.006251
# ETH     0.07...     23984.01
# 2020-12-28        2020-12-28
# BTC     0.030458
# ETH     0.06...     24895.42
# 2020-12-29        2020-12-29
# BTC     0.010198
# ETH     0.00...     24925.16
# 2020-12-30        2020-12-30
# BTC     0.052625
# ETH     0.02...     26338.46
#
#             Market_Return
# 2020-01-01       0.000000
# 2020-01-02      -0.041867
# 2020-01-03       0.053687
# 2020-01-04       0.003412
# 2020-01-05       0.016488
# ...                   ...
# 2020-12-26       0.069255
# 2020-12-27      -0.006712
# 2020-12-28       0.037296
# 2020-12-29       0.001194
# 2020-12-30       0.055152
#
# [360 rows x 6 columns]

# %%
df_tmp = result[['Capital','MarketIndex']]
df_tmp['MarketIndex'] /= df_tmp['MarketIndex'][0]
df_tmp['Capital'] /= df_tmp['Capital'][0]
df_tmp.plot(figsize = (26,10))
# Out:
# <AxesSubplot:>

# %%
result[['Actual_Return','Market_Return']].plot(figsize = (26,10))
# Out:
# <AxesSubplot:>

# %%
import empyrical 

def result_analysis(result):
    res = pd.DataFrame(columns=['Strategy', 'Market'], index=['Return','Max_drawdown','Annual_volatility','Sharpe_ratio','Calmar_ratio','Alpha','Beta','Tail_ratio'])
    res.loc['Return']['Strategy'] = f"{(result['Capital'][-1]/result['Capital'][0] - 1)*100:.2f}%"
    res.loc['Return']['Market'] = f"{(result['MarketIndex'][-1]/result['MarketIndex'][0] - 1)*100:.2f}%"
    
    res.loc['Max_drawdown']['Strategy'] = f"{empyrical.max_drawdown(result['Actual_Return'])*100:.2f}%"
    res.loc['Max_drawdown']['Market'] = f"{empyrical.max_drawdown(result['Market_Return'])*100:.2f}%"
    
    res.loc['Annual_volatility']['Strategy']  = empyrical.annual_volatility(result['Actual_Return'],period = 'daily')
    res.loc['Annual_volatility']['Market']  = empyrical.annual_volatility(result['Market_Return'],period = 'daily')
    
    res.loc['Sharpe_ratio']['Strategy']  = empyrical.sharpe_ratio(result['Actual_Return'],risk_free=0,period = 'daily')
    res.loc['Sharpe_ratio']['Market']  = empyrical.sharpe_ratio(result['Market_Return'],risk_free=0,period = 'daily')
    
    res.loc['Calmar_ratio']['Strategy']  = empyrical.calmar_ratio(result['Actual_Return'],period = 'daily')
    res.loc['Calmar_ratio']['Market']  = empyrical.calmar_ratio(result['Market_Return'],period = 'daily')
    
    res.loc['Alpha']['Strategy']  = empyrical.alpha_beta(result['Actual_Return'],result['Market_Return'],risk_free=0,period = 'daily')[0]
    res.loc['Alpha']['Market']  = empyrical.alpha_beta(result['Market_Return'],result['Market_Return'],risk_free=0,period = 'daily')[0]
    
    res.loc['Beta']['Strategy']  = empyrical.alpha_beta(result['Actual_Return'],result['Market_Return'],risk_free=0,period = 'daily')[1]
    res.loc['Beta']['Market']  = empyrical.alpha_beta(result['Market_Return'],result['Market_Return'],risk_free=0,period = 'daily')[1]
    
    res.loc['Tail_ratio']['Strategy']  = empyrical.tail_ratio(result['Actual_Return'])
    res.loc['Tail_ratio']['Market']  = empyrical.tail_ratio(result['Market_Return'])
    
    return res

result_analysis(result)
# Out:
#                    Strategy    Market
# Return              583.63%   272.60%
# Max_drawdown        -37.96%   -58.52%
# Annual_volatility  0.720398  0.570234
# Sharpe_ratio       2.236663   1.50295
# Calmar_ratio       7.528396  1.690312
# Alpha              2.861595       0.0
# Beta               0.299381       1.0
# Tail_ratio          1.26341  1.040407

# %% [markdown]
# # Strategy with long & short position
# # Need to test the conditions of that we don't hold any CC

# %%
TEST_START = '2020-01-01'
TEMP_DATE = '2020-03-25'
CC_daily_data=pd.read_csv('CC_daily_data.csv').dropna()
capital = 1
performance = pd.DataFrame(columns = ['Date','Actual_Return','Capital','Allocation','Top10CC_real_return'])

for date in top10CC.loc[TEST_START:].index:
    if date not in data_BTC.index:
        continue
    
    # Initialize variables
    top10CC_predicted_return = pd.DataFrame(columns = ['Ticker','Predicted_Return'])
    top10CC_historical_return = pd.DataFrame()
    
    # Get expected(predicted) returns on the "date", and the previous real returns before the date
    for  CC_name in ast.literal_eval(top10CC.loc[date]['top10_Market']):
        exec(f"return_temp = data_{CC_name}.loc[date]['predictions']")
        top10CC_predicted_return = top10CC_predicted_return.append({'Ticker':CC_name,'Predicted_Return':return_temp},ignore_index = True)
        top10CC_historical_return = pd.concat([top10CC_historical_return,find_top10CC_historical_returns(CC_name,CC_daily_data)],axis = 1).dropna()
        
    top10CC_predicted_return = top10CC_predicted_return.set_index('Ticker')
    top10CC_real_return = top10CC_historical_return.loc[date].to_frame()
    top10CC_historical_return = top10CC_historical_return.loc[:date][:-1]
    
    return_sum = weights = 0
    top10CC_predicted_return_temp = top10CC_predicted_return[top10CC_predicted_return>0].dropna()
    if len(top10CC_predicted_return_temp) > 4:  
        # Get the optimal weight of top10CC on the "date"
        weights = find_optimal_weights_LS(top10CC_predicted_return['Predicted_Return'],top10CC_historical_return.cov())
        # Calcualte the real gain/loss on the "date"
        return_sum = (np.array(list(weights.values())).reshape(-1,1) * top10CC_real_return).sum()[0]
        
    capital *= (1+return_sum)
    performance = performance.append({'Date':date,'Actual_Return': return_sum,'Capital':capital,'Allocation':weights,"Top10CC_real_return":top10CC_real_return},ignore_index= True)
    print(f"Date: {date}   Return: {return_sum:4f}  Capital: {capital:4f}")
    
performance
# Out:
# Date: 2020-01-01   Return: 0.046782  Capital: 1.046782
# Date: 2020-01-02   Return: -0.058257  Capital: 0.985799
# Date: 2020-01-03   Return: 0.108517  Capital: 1.092775
# Date: 2020-01-04   Return: 0.018246  Capital: 1.112714
# Date: 2020-01-05   Return: 0.078847  Capital: 1.200448
# Date: 2020-01-06   Return: -0.024108  Capital: 1.171507
# Date: 2020-01-07   Return: 0.025398  Capital: 1.201261
# Date: 2020-01-08   Return: 0.023406  Capital: 1.229377
# Date: 2020-01-09   Return: -0.017729  Capital: 1.207582
# Date: 2020-01-10   Return: -0.032420  Capital: 1.168432
# Date: 2020-01-11   Return: -0.019507  Capital: 1.145639
# Date: 2020-01-12   Return: 0.050858  Capital: 1.203904
# Date: 2020-01-13   Return: -0.027991  Capital: 1.170206
# BTC   -0.030273
# ETH   -0.02627...
# 2         2020-01-03
# BTC    0.050172
# ETH    0.05170...
# 3         2020-01-04
# BTC    0.008915
# ETH    0.00666...
# 4         2020-01-05
# BTC    0.000089
# ETH    0.00889...
# ..                                                 ...
# 355        2020-12-26
# BTC     0.069389
# ETH     0.01...
# 356        2020-12-27
# BTC    -0.006251
# ETH     0.07...
# 357        2020-12-28
# BTC     0.030458
# ETH     0.06...
# 358        2020-12-29
# BTC     0.010198
# ETH     0.00...
# 359        2020-12-30
# BTC     0.052625
# ETH     0.02...
#
# [360 rows x 5 columns]

# %%
result = pd.concat([performance.set_index('Date'), CC100_Index], axis = 1).dropna()
result
# Out:
#             Actual_Return    Capital  \
# 2020-01-01       0.046782   1.046782
# 2020-01-02      -0.058257   0.985799
# 2020-01-03       0.108517   1.092775
# 2020-01-04       0.018246   1.112714
# 2020-01-05       0.078847   1.200448
# ...                   ...        ...
# 2020-12-26       0.164397  11.573289
# 2020-12-27       0.105423  12.793381
# 2020-12-28       0.267418  16.214561
# 2020-12-29       0.205244  19.542507
# 2020-12-30       0.083552  21.175329
#
#                                                    Allocation  \
# 2020-01-01  {'BTC': 1.0, 'ETH': 0.72718, 'XRP': -0.95236, ...
# 2020-01-02  {'BTC': 1.0, 'ETH': 0.34058, 'XRP': -1.0, 'BCH...
# 2020-01-03  {'BTC': 1.0, 'ETH': 0.77021, 'XRP': -0.53287, ...
# 2020-01-04  {'BTC': 0.71548, 'ETH': -0.24408, 'XRP': -1.0,...
# 2020-01-05  {'BTC': 0.31112, 'ETH': 0.76072, 'XRP': -0.846...
# ...                                                       ...
# 2020-12-26  {'BTC': 1.0, 'ETH': 0.02057, 'XRP': -1.0, 'LTC...
# 2020-12-27  {'BTC': 1.0, 'ETH': 0.34758, 'XRP': -1.0, 'LTC...
# 2020-12-28  {'BTC': 0.75137, 'ETH': 0.5307, 'XRP': -1.0, '...
# 2020-12-29  {'BTC': 1.0, 'ETH': 1.0, 'XRP': -1.0, 'LTC': 0...
# 2020-12-30  {'BTC': 0.68539, 'ETH': 0.77864, 'XRP': -1.0, ...
#
#                                           Top10CC_real_return  MarketIndex  \
# 2020-01-01       2020-01-01
# BTC    0.000914
# ETH    0.00914...      7068.77
# 2020-01-02       2020-01-02
# BTC   -0.030273
# ETH   -0.02627...      6778.93
# 2020-01-03       2020-01-03
# BTC    0.050172
# ETH    0.05170...      7152.82
# 2020-01-04       2020-01-04
# BTC    0.008915
# ETH    0.00666...      7177.27
# 2020-01-05       2020-01-05
# BTC    0.000089
# ETH    0.00889...      7296.59
# ...                                                       ...          ...
# 2020-12-26        2020-12-26
# BTC     0.069389
# ETH     0.01...     24145.53
# 2020-12-27        2020-12-27
# BTC    -0.006251
# ETH     0.07...     23984.01
# 2020-12-28        2020-12-28
# BTC     0.030458
# ETH     0.06...     24895.42
# 2020-12-29        2020-12-29
# BTC     0.010198
# ETH     0.00...     24925.16
# 2020-12-30        2020-12-30
# BTC     0.052625
# ETH     0.02...     26338.46
#
#             Market_Return
# 2020-01-01       0.000000
# 2020-01-02      -0.041867
# 2020-01-03       0.053687
# 2020-01-04       0.003412
# 2020-01-05       0.016488
# ...                   ...
# 2020-12-26       0.069255
# 2020-12-27      -0.006712
# 2020-12-28       0.037296
# 2020-12-29       0.001194
# 2020-12-30       0.055152
#
# [360 rows x 6 columns]

# %%
df_tmp = result[['Capital','MarketIndex']]
df_tmp['MarketIndex'] /= df_tmp['MarketIndex'][0]
df_tmp['Capital'] /= df_tmp['Capital'][0]
df_tmp.plot(figsize = (26,10))
# Out:
# <AxesSubplot:>

# %%
result[['Actual_Return','Market_Return']].plot(figsize = (26,10))
# Out:
# <AxesSubplot:>

# %%
import empyrical 

def result_analysis(result):
    res = pd.DataFrame(columns=['Strategy', 'Market'], index=['Return','Max_drawdown','Annual_volatility','Sharpe_ratio','Calmar_ratio','Alpha','Beta','Tail_ratio'])
    res.loc['Return']['Strategy'] = f"{(result['Capital'][-1]/result['Capital'][0] - 1)*100:.2f}%"
    res.loc['Return']['Market'] = f"{(result['MarketIndex'][-1]/result['MarketIndex'][0] - 1)*100:.2f}%"
    
    res.loc['Max_drawdown']['Strategy'] = f"{empyrical.max_drawdown(result['Actual_Return'])*100:.2f}%"
    res.loc['Max_drawdown']['Market'] = f"{empyrical.max_drawdown(result['Market_Return'])*100:.2f}%"
    
    res.loc['Annual_volatility']['Strategy']  = empyrical.annual_volatility(result['Actual_Return'],period = 'daily')
    res.loc['Annual_volatility']['Market']  = empyrical.annual_volatility(result['Market_Return'],period = 'daily')
    
    res.loc['Sharpe_ratio']['Strategy']  = empyrical.sharpe_ratio(result['Actual_Return'],risk_free=0,period = 'daily')
    res.loc['Sharpe_ratio']['Market']  = empyrical.sharpe_ratio(result['Market_Return'],risk_free=0,period = 'daily')
    
    res.loc['Calmar_ratio']['Strategy']  = empyrical.calmar_ratio(result['Actual_Return'],period = 'daily')
    res.loc['Calmar_ratio']['Market']  = empyrical.calmar_ratio(result['Market_Return'],period = 'daily')
    
    res.loc['Alpha']['Strategy']  = empyrical.alpha_beta(result['Actual_Return'],result['Market_Return'],risk_free=0,period = 'daily')[0]
    res.loc['Alpha']['Market']  = empyrical.alpha_beta(result['Market_Return'],result['Market_Return'],risk_free=0,period = 'daily')[0]
    
    res.loc['Beta']['Strategy']  = empyrical.alpha_beta(result['Actual_Return'],result['Market_Return'],risk_free=0,period = 'daily')[1]
    res.loc['Beta']['Market']  = empyrical.alpha_beta(result['Market_Return'],result['Market_Return'],risk_free=0,period = 'daily')[1]
    
    res.loc['Tail_ratio']['Strategy']  = empyrical.tail_ratio(result['Actual_Return'])
    res.loc['Tail_ratio']['Market']  = empyrical.tail_ratio(result['Market_Return'])
    
    return res

result_analysis(result)
# Out:
#                     Strategy    Market
# Return              1922.90%   272.60%
# Max_drawdown         -57.34%   -58.52%
# Annual_volatility   1.096141  0.570234
# Sharpe_ratio             2.5   1.50295
# Calmar_ratio       13.035001  1.690312
# Alpha               11.18831       0.0
# Beta                0.265368       1.0
# Tail_ratio          1.475466  1.040407
