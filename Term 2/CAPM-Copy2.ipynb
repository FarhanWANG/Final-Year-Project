# %%
import pandas as pd
import numpy as np
import datetime
from yahoo_fin.stock_info import get_data,get_quote_table
import statsmodels.formula.api as smf
from pypfopt.efficient_frontier import EfficientFrontier

import json
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects

# %%
CC_string = "ADA,ADX,AE,ANT,ARDR,ARK,BAT,BCH,BCN,BNB,BNT,BTC,BTG,BTS,CVC,DASH,DCR,DGB,DGD,DNT,DOGE,EDG,EOS,ETC,ETH,FUN,GAS,GBYTE,GNO,HC,ICX,KIN,KMD,KNC,LINK,LRC,LSK,LTC,MAID,MCO,MIOTA,MLN,MONA,MTL,NANO,NEO,NXS,OMG,PIVX,PPT,QRL,QTUM,REP,RLC,SALT,SC,SNT,STEEM,STORJ,SYS,TRX,VERI,VET,WAVES,WTC,XEM,XLM,XMR,XRP,XVG,ZEC,ZEN,ZRX"
CC_temp_list = CC_string.split(",")
CC_list = [i+'-USD' for i in CC_temp_list]

# %%
Market_Cap.loc['BTC-USD']['Market Cap']
# Out:
# nan

# %%
Market_Cap = pd.DataFrame(index = CC_list,columns = ['Market Cap'])
for i in CC_list:
    print(i)
    cap = get_quote_table(i)['Market Cap']
    print(cap[-1])
#     if cap[-1] == 'B':
#         Market_Cap.index[i]['Market Cap'] = float(cap.split('B')[0])*1000
#     else:
#         Market_Cap.index[i]['Market Cap'] = float(cap.split('M')[0])
# Out:
# ADA-USD
# B
# ADX-USD
# M
# AE-USD
# M
# ANT-USD
# M
# ARDR-USD
# M
# ARK-USD
# M
# BAT-USD
# M
# BCH-USD
# B
# BCN-USD
# M
# BNB-USD
# B
# BNT-USD
# M
# BTC-USD
# B
# BTG-USD
# M
# BTS-USD
# M
# CVC-USD
# M
# DASH-USD
# M
# DCR-USD
# M
# DGB-USD
# M
# DGD-USD
# M
# DNT-USD
# M
# DOGE-USD
# B
# EDG-USD
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-7d5365450adf> in <module>
#       3     print(i)
#       4     cap = get_quote_table(i)['Market Cap']
# ----> 5     print(cap[-1])
#       6 #     if cap[-1] == 'B':
#       7 #         Market_Cap.index[i]['Market Cap'] = float(cap.split('B')[0])*1000
#
# TypeError: 'float' object is not subscriptable

# %%
test = get_quote_table('EDG-USD')['Market Cap']

# %%
test
# Out:
# 337249.0

# %%
float(test.split('B')[0])
# Out:
# 581.225

# %%
#Output the top 10 CC
def top10MarketCapCC():    
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/quotes/latest?convert=USD'
    parameters = {
        'symbol' : 'ADA,ADX,AE,ANT,ARDR,ARK,BAT,BCH,BCN,BNB,BNT,BTC,BTG,BTS,CVC,DASH,DCR,DGB,DGD,DNT,DOGE,EDG,EOS,ETC,ETH,FUN,GAS,GBYTE,GNO,HC,ICX,KIN,KMD,KNC,LINK,LRC,LSK,LTC,MAID,MCO,MIOTA,MLN,MONA,MTL,NANO,NEO,NXS,OMG,PIVX,PPT,QRL,QTUM,REP,RLC,SALT,SC,SNT,STEEM,STORJ,SYS,TRX,VERI,VET,WAVES,WTC,XEM,XLM,XMR,XRP,XVG,ZEC,ZEN,ZRX'
    }
    headers = {
        'Accepts': 'application/json',
    #Input your API key here
        'X-CMC_PRO_API_KEY': '4797f5ee-9a2d-42d1-979a-ae14643c966d',
    }
    session = Session()
    session.headers.update(headers)
    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
        result = data
        d = pd.DataFrame(result)
        f = d.iloc[6:,1]
        MarketCap_rank = pd.DataFrame(columns = ['Symbol', 'MarketCap'])
        for i in range(73):
            Append = {'Symbol': f.iloc[i]['symbol'], 'MarketCap' : f.iloc[i]['quote']['USD']['market_cap']}
            MarketCap_rank = MarketCap_rank.append(Append, ignore_index=True)
        MarketCap_rank = MarketCap_rank.sort_values(by=['MarketCap'], ascending = False)
        MarketCap_rank.reset_index(drop=True, inplace=True)
        MarketCap_rank = MarketCap_rank.truncate(before=None, after=9, copy=True)
        return MarketCap_rank#['Symbol'] + '-USD'
    except (ConnectionError, Timeout, TooManyRedirects) as e:
        print(e)

# %%
top10MarketCapCC_list = top10MarketCapCC()

# %%
top10MarketCapCC_list
# Out:
#   Symbol     MarketCap
# 0    BTC  5.820904e+11
# 1    ETH  1.467132e+11
# 2    XRP  1.162548e+10
# 3    ADA  1.020338e+10
# 4   LINK  9.244747e+09
# 5    LTC  8.427989e+09
# 6    BCH  7.277673e+09
# 7    BNB  6.497097e+09
# 8    XLM  5.482135e+09
# 9    EOS  2.408985e+09

# %%
weekly_data = get_data("ADA-USD", interval = "1wk")

# %%
weekly_data
# Out:
#                 open      high       low     close  adjclose        volume  \
# 2017-09-24  0.021678  0.032226  0.017354  0.024969  0.024969  5.006870e+07
# 2017-10-01  0.024607  0.030088  0.017620  0.020477  0.020477  1.121211e+08
# 2017-10-08  0.020344  0.038268  0.020342  0.030049  0.030049  7.024806e+07
# 2017-10-15  0.029939  0.030855  0.024637  0.027729  0.027729  3.546097e+07
# 2017-10-22  0.027684  0.029837  0.023766  0.028607  0.028607  2.510283e+07
# ...              ...       ...       ...       ...       ...           ...
# 2021-01-04  0.205236  0.353344  0.194450  0.304895  0.304895  3.062729e+10
# 2021-01-11  0.304996  0.395653  0.233033  0.379852  0.379852  2.741545e+10
# 2021-01-18  0.379735  0.395443  0.363624  0.369137  0.369137  6.437736e+09
# 2021-01-25       NaN       NaN       NaN       NaN       NaN           NaN
# 2021-01-28  0.312822  0.321835  0.307351  0.319436  0.319436  2.812321e+09
#
#              ticker
# 2017-09-24  ADA-USD
# 2017-10-01  ADA-USD
# 2017-10-08  ADA-USD
# 2017-10-15  ADA-USD
# 2017-10-22  ADA-USD
# ...             ...
# 2021-01-04  ADA-USD
# 2021-01-11  ADA-USD
# 2021-01-18  ADA-USD
# 2021-01-25  ADA-USD
# 2021-01-28  ADA-USD
#
# [176 rows x 7 columns]

# %%
#Output market returns
def MarketReturns(CC_list):
    data = pd.DataFrame()
    end = datetime.date.today()
    start = datetime.datetime.now() - datetime.timedelta(days = 7 * 8)
    for i in CC_list:
        data[i] = get_data(i, start, end,True, '1d')['adjclose']
    data= data.fillna(value=.001)#Usd because faulty API returns NaN values
    marketData = np.log(data/ data.shift(1)).fillna(value=0.001)
    sum_row = marketData.sum(axis=1)
    return sum_row

# %%
I = MarketReturns(CC_list)

# %%
J = pd.DataFrame(I, columns = ['MarketReturns'])

# %%
#Load the list of CC used in the research
end = datetime.date.today()
start = datetime.datetime.now() - datetime.timedelta(days = 7 * 8)

data = pd.DataFrame()
for i in top10MarketCapCC_list:
    data[i] = get_data(i, start, end,True, '1d')['adjclose']
data= data.fillna(value=.001)
marketData = np.log(data/ data.shift(1)).fillna(value=0.001)

# %%
result = pd.concat([marketData.rename(columns=lambda s: s.replace('-USD','')), J], axis=1)

# %%
result.mean()
result.std()
# Out:
# BTC               3.275064
# ETH               2.664746
# XRP               1.066105
# ADA               1.106031
# LINK              1.886942
# LTC               2.238967
# BCH               2.458851
# BNB               2.013599
# XLM               1.063423
# EOS               1.492463
# MarketReturns    96.345611
# dtype: float64

# %%
Name = list(result.iloc[:,0:10])
regression = pd.DataFrame(columns=['beta', 'rse'])
for i in range(10):
    CAPM_model = smf.ols(formula = Name[i]+' ~ MarketReturns', data = result)
    CAPM_fit = CAPM_model.fit()
    beta = CAPM_fit.params['MarketReturns']
    rse = CAPM_fit.bse['MarketReturns']
    dict = {'beta': beta, 'rse': rse} 
    df = pd.DataFrame(dict, index = [Name[i]])
    regression = regression.append(df)
    
print(regression)
# Out:
#           beta       rse
# BTC   0.033982  0.000118
# ETH   0.027653  0.000073
# XRP   0.011029  0.000122
# ADA   0.011467  0.000072
# LINK  0.019578  0.000074
# LTC   0.023235  0.000060
# BCH   0.025516  0.000072
# BNB   0.020894  0.000064
# XLM   0.011001  0.000121
# EOS   0.015487  0.000048

# %%
def calculateReturns(x):
    for i in range(10):
        y = str(x[i:i+1]).split(' ')[0]
        x[i] = result.mean()['MarketReturns'] * regression.loc[y]['beta']
    return x

# %%
ExpectedReturns = pd.DataFrame(index = ['returns'],columns = list(result.iloc[:,0:10]))
ExpectedReturns = ExpectedReturns.apply(lambda x: calculateReturns(x), axis=1) 
ExpectedReturns.T
# Out:
#        returns
# BTC   0.010644
# ETH   0.008662
# XRP   0.003454
# ADA   0.003592
# LINK  0.006132
# LTC   0.007278
# BCH   0.007992
# BNB   0.006545
# XLM   0.003446
# EOS   0.004851

# %%
def calculateCovariance(x):
    for i in range(10):
        y = str(x[i:i+1]).split(' ')[0]
        if(y == x.name):
            x[i] = (result.std()['MarketReturns'] * regression.loc[y]['beta']) ** 2 + regression.loc[y]['rse']
        else:
            x[i] = (result.std()['MarketReturns'] ** 2) * (regression.loc[y]['beta'] * regression.loc[x.name]['beta'])
    return x

# %%
CovarianceMatrix = pd.DataFrame(index = list(result.iloc[:,0:10]),columns = list(result.iloc[:,0:10]))
CovarianceMatrix = CovarianceMatrix.apply(lambda x: calculateCovariance(x), axis=1) 
CovarianceMatrix
# Out:
#             BTC       ETH       XRP       ADA      LINK       LTC       BCH  \
# BTC   10.719041  8.722660  3.478810  3.617184  6.175410  7.328985  8.048460
# ETH    8.722660  7.098248  2.830926  2.943529  5.025318  5.964055  6.549537
# XRP    3.478810  2.830926  1.129164  1.173951  2.004220  2.378611  2.612115
# ADA    3.617184  2.943529  1.173951  1.220719  2.083940  2.473223  2.716015
# LINK   6.175410  5.025318  2.004220  2.083940  3.557864  4.222391  4.636897
# LTC    7.328985  5.964055  2.378611  2.473223  4.222391  5.011199  5.503076
# BCH    8.048460  6.549537  2.612115  2.716015  4.636897  5.503076  6.043376
# BNB    6.590797  5.363345  2.139033  2.224115  3.797104  4.506409  4.948796
# XLM    3.470066  2.823811  1.126205  1.171001  1.999182  2.372632  2.605550
# EOS    4.885003  3.975233  1.585420  1.648482  2.814359  3.340085  3.667976
#
#            BNB       XLM       EOS
# BTC   6.590797  3.470066  4.885003
# ETH   5.363345  2.823811  3.975233
# XRP   2.139033  1.126205  1.585420
# ADA   2.224115  1.171001  1.648482
# LINK  3.797104  1.999182  2.814359
# LTC   4.506409  2.372632  3.340085
# BCH   4.948796  2.605550  3.667976
# BNB   4.052579  2.133657  3.003666
# XLM   2.133657  1.123495  1.581435
# EOS   3.003666  1.581435  2.226321

# %%
ef1 = EfficientFrontier(ExpectedReturns.iloc[0], CovarianceMatrix, weight_bounds=(0, 1))
weights = ef1.max_sharpe(risk_free_rate= 0.0)
weights = ef1.clean_weights()

weights
# Out:
# OrderedDict([('BTC', 0.10777),
#              ('ETH', 0.14263),
#              ('XRP', 0.034),
#              ('ADA', 0.05954),
#              ('LINK', 0.09978),
#              ('LTC', 0.14528),
#              ('BCH', 0.1328),
#              ('BNB', 0.12307),
#              ('XLM', 0.03401),
#              ('EOS', 0.12112)])
